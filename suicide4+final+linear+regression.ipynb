# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("C:\suicide_rate_dataset.csv")
print((dataset[["suicides_no","suicides/100k pop"]]==0).sum())
dataset[["suicides_no","suicides/100k pop"]]=dataset[["suicides_no","suicides/100k pop"]].replace(0,np.NaN)
dataset.fillna(dataset.mean(),inplace=True)
dataset.head(20)
# Out:
# suicides_no          4281
# suicides/100k pop    4281
# dtype: int64
#     country  year     sex          age  suicides_no  population  \
# 0   Albania  1987    male  15-24 years    21.000000      312900
# 1   Albania  1987    male  35-54 years    16.000000      308000
# 2   Albania  1987  female  15-24 years    14.000000      289700
# 3   Albania  1987    male    75+ years     1.000000       21800
# 4   Albania  1987    male  25-34 years     9.000000      274300
# 5   Albania  1987  female    75+ years     1.000000       35600
# 6   Albania  1987  female  35-54 years     6.000000      278800
# 7   Albania  1987  female  25-34 years     4.000000      257200
# 8   Albania  1987    male  55-74 years     1.000000      137500
# 9   Albania  1987  female   5-14 years   286.691023      311000
# 10  Albania  1987  female  55-74 years   286.691023      144600
# 11  Albania  1987    male   5-14 years   286.691023      338200
# 12  Albania  1988  female    75+ years     2.000000       36400
# 13  Albania  1988    male  15-24 years    17.000000      319200
# 14  Albania  1988    male    75+ years     1.000000       22300
# 15  Albania  1988    male  35-54 years    14.000000      314100
# 16  Albania  1988    male  55-74 years     4.000000      140200
# 17  Albania  1988  female  15-24 years     8.000000      295600
# 18  Albania  1988  female  55-74 years     3.000000      147500
# 19  Albania  1988  female  25-34 years     5.000000      262400
#
#     suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0             6.71000  Albania1987      0.776601      2,156,624,900
# 1             5.19000  Albania1987      0.776601      2,156,624,900
# 2             4.83000  Albania1987      0.776601      2,156,624,900
# 3             4.59000  Albania1987      0.776601      2,156,624,900
# 4             3.28000  Albania1987      0.776601      2,156,624,900
# 5             2.81000  Albania1987      0.776601      2,156,624,900
# 6             2.15000  Albania1987      0.776601      2,156,624,900
# 7             1.56000  Albania1987      0.776601      2,156,624,900
# 8             0.73000  Albania1987      0.776601      2,156,624,900
# 9            15.14694  Albania1987      0.776601      2,156,624,900
# 10           15.14694  Albania1987      0.776601      2,156,624,900
# 11           15.14694  Albania1987      0.776601      2,156,624,900
# 12            5.49000  Albania1988      0.776601      2,126,000,000
# 13            5.33000  Albania1988      0.776601      2,126,000,000
# 14            4.48000  Albania1988      0.776601      2,126,000,000
# 15            4.46000  Albania1988      0.776601      2,126,000,000
# 16            2.85000  Albania1988      0.776601      2,126,000,000
# 17            2.71000  Albania1988      0.776601      2,126,000,000
# 18            2.03000  Albania1988      0.776601      2,126,000,000
# 19            1.91000  Albania1988      0.776601      2,126,000,000
#
#     gdp_per_capita ($)       generation
# 0                  796     Generation X
# 1                  796           Silent
# 2                  796     Generation X
# 3                  796  G.I. Generation
# 4                  796          Boomers
# 5                  796  G.I. Generation
# 6                  796           Silent
# 7                  796          Boomers
# 8                  796  G.I. Generation
# 9                  796     Generation X
# 10                 796  G.I. Generation
# 11                 796     Generation X
# 12                 769  G.I. Generation
# 13                 769     Generation X
# 14                 769  G.I. Generation
# 15                 769           Silent
# 16                 769  G.I. Generation
# 17                 769     Generation X
# 18                 769  G.I. Generation
# 19                 769          Boomers

# %%
x=dataset.drop(["suicides/100k pop"],axis=1)
y=dataset["suicides/100k pop"]
data=pd.concat([x,y],axis=1)

data2=data.corr('pearson')
data2
abs(data2['suicides_no']).sort_values(ascending=False)
# Out:
# suicides_no           1.000000
# population            0.598344
# suicides/100k pop     0.287570
# HDI for year          0.059259
# gdp_per_capita ($)    0.056531
# year                  0.005592
# Name: suicides_no, dtype: float64

# %%
X = data['suicides_no']
Y = data['suicides/100k pop']

X = np.array((X - X.min())/(X.max() - X.min()))
Y = np.array((Y - Y.min())/(Y.max() - Y.min()))

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)
plt.plot(x_train, y_train, 'r.')
plt.show()
plt.plot(x_test, y_test, 'r.')
plt.show()

# %%
def hypothesis(a,b,x):
    return a * x  + b

def error(a,b,x,y):
    e = 0
    m = len(y)
    for i in range(m):
        e += np.power((hypothesis(a,b,x[i]) - y[i]), 2)
    
    return (1/(2 * m)) * e

def step_gradient(a,b,x,y,learning_rate):
    grad_a=0
    grad_b=0
    m=len(x)
    for i in range(m):
        grad_a += 1/m * (hypothesis(a,b,x[i]) - y[i]) * x[i]
        grad_b += 1/m * hypothesis(a,b,x[i]) - y[i]
    a = a - (grad_a * learning_rate)
    b = b - (grad_b * learning_rate)
    return a,b

def descend(initial_a, initial_b, x, y, learning_rate, iterations):
    a = initial_a
    b = initial_b
    for i in range(iterations):
        e = error(a, b, x ,y)
        if i % 1000 == 0:
            print(f"Error: {e}, a: {a}, b: {b}")
        a, b = step_gradient(a, b, x, y, learning_rate)
    return a, b

# %%
a=0
b=1
learning_rate=0.01
iterations=10000
final_a,final_b=descend(a,b,x_train,y_train,learning_rate,iterations)

print(error(a,b,x_train,y_train))
print(error(final_a, final_b, x_train, y_train))
print(error(final_a, final_b, x_test, y_test))

plt.plot(x_train, y_train, 'r.', x_train, hypothesis(a, b, x_train), 'g', x_train, hypothesis(final_a, final_b, x_train), 'b', )
plt.show()
plt.plot(x_test, y_test, 'r.', x_test, hypothesis(final_a, final_b, x_test), 'g')
plt.show()

print(str((1-error(final_a, final_b, x_test, y_test))*100) + " %")
# Out:
# Error: 0.43828543318003477, a: 0, b: 1
